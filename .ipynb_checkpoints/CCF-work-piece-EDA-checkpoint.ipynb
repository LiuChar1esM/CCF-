# %%
import pandas as pd
pd.set_option('display.max_column',30) #最大展示列
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()  # seems to be changing the background color of the plot

from pylab import rcParams ## matplotlib
rcParams['figure.figsize'] = 12,8

# %%
train = pd.read_csv('data/first_round_training_data.csv')[['Parameter'+str(i) for i in range(1,11)]+['Quality_label']]
test = pd.read_csv('data/first_round_testing_data.csv')

# %%
train.head(100)
# Out:
#       Parameter1   Parameter2   Parameter3   Parameter4  Parameter5  \
# 0       0.001660     0.591013   147.608373    38.186345    0.000421
# 1       1.601749     0.015052     0.035864    51.130326    0.000909
# 2       0.098039    69.233685     0.080920     0.112265    0.000909
# 3      18.181860     0.047325     0.018061     1.098102    0.000909
# 4       0.012085     0.008749     0.005509   524.327396    0.000909
# 5       0.004062    14.556483     0.786945     0.010545    0.000525
# 6       0.438449     1.232559     2.882699     0.610757    1.600654
# 7   48159.917401     0.002987    14.863813     0.063287    1.434060
# 8       1.456601    52.381578    20.625283   366.074831    1.434060
# 9       0.000109     4.784654    31.916672    20.672388    1.284806
# 10     12.460323    75.940337     0.051241     0.710990    1.600654
# 11      0.778409     9.256197    74.335935     2.982123    1.600654
# 12      0.000758     0.022673   199.656582     3.761593    1.600654
# 13     87.024169     0.077502   228.004391     0.732292    1.786601
# 14      2.850770  1263.088796     5.224137    33.257218    1.600654
# 15      0.002539     4.619355    38.408901     0.526750    2.225808
# 16      0.234521    16.310746  2264.226344   375.640582    1.284806
# 17     13.296633     0.015196   476.841807     1.292070    2.225808
# 18      0.220540   262.193593     4.283587     1.539753    3.454681
# 19      0.204164     5.166550     0.299501     0.051691    3.856009
# 20     35.597937     0.412561     0.062601    51.426701    3.856009
# 21      1.349670     0.005561    73.363445     0.606519    5.362018
# 22      0.029588     1.853347     1.437164  1505.668106    5.984919
# 23     41.990986     0.241055    81.851090     0.031341    4.303959
# 24      0.318964     0.000281     0.001396     0.000869    5.362018
# 25      0.126287     0.145322     0.022314     0.145914    5.362018
# 26      0.184011     2.146057     2.399497  1999.715246    3.095123
# 27      0.055858     0.022870  1122.396003     0.001256    3.095123
# 28      0.004220     0.019195     2.047142     0.003749    3.095123
# 29     12.626264     4.368145     0.216117     1.851174    3.095123
# ..           ...          ...          ...          ...         ...
# 70      0.080735     0.124690     0.226550     0.151133   14.417794
# 71      3.569445     2.861244     0.182979     0.082550    8.322398
# 72      0.067331    50.335350   437.209145    53.737360    7.456215
# 73      1.104894     2.223771   133.098713     0.749079    0.664442
# 74      0.771768     0.044705     1.426204    27.874432    0.664442
# 75     14.437712     4.238576     2.235867     2.331668    0.664442
# 76      2.408609     0.112168     0.000753     0.003972   60.171339
# 77     73.538862     2.531167     4.693639     0.413397    0.595288
# 78     32.137496     0.759673     0.798216     0.018473    0.664442
# 79     66.740328     4.059531    33.239196     0.000590    0.003794
# 80    192.538603     0.005395     0.192045     0.452255   11.572807
# 81    122.033787     0.073974  1579.193245     2.215084   12.917211
# 71   12.777380     2.374035   14.603595    0.051850     0.377332
# 72   10.513382     2.374035   14.603595    0.051850     0.377332
# 73    2.208755     0.038483   17.850021    0.004533     0.007340
# 74    2.208755     0.038483   17.850021    0.004533     0.007340
# 75    2.208755     0.038483   17.850021    0.004533     0.007340
# 76   15.528917     0.600827   17.850021    0.593081     0.073078
# 77    0.563965     0.038483   17.850021    0.593081     0.073078
# 78    0.314162     0.038483   17.850021    0.593081     0.073078
# 79    0.007724   578.679288    0.035407    0.593081     0.005285
# 80   22.937172     0.152059    0.035407    0.593081    37.407054
# 81   22.937172     0.152059    0.035407    0.593081    37.407054
# 82   22.937172     0.152059    0.035407    0.593081    37.407054
# 83   18.872982     0.152059    0.035407    0.593081    37.407054
# 84   15.528917     0.152059    0.035407    0.593081    37.407054
# 85   15.528917     0.152059    0.035407    0.593081    37.407054
# 86   33.879624     0.152059    0.035407    0.593081    37.407054
# 87   33.879624     0.152059    0.035407    0.593081    37.407054
# 88   33.879624     0.152059    0.035407    0.593081    37.407054
# 89   27.876563     0.152059    0.035407    0.593081    37.407054
# 90   22.937172     0.152059    0.035407    0.593081    37.407054
# 91   15.528917     0.152059    0.035407    0.593081    37.407054
# 92   15.528917     0.152059    0.035407    0.593081    37.407054
# 93   15.528917     0.152059    0.035407    0.593081    37.407054
# 94   12.777380     0.152059    0.035407    0.593081    37.407054
# 95   12.777380     0.152059    0.035407    0.593081    37.407054
# 96   10.513382     0.152059    0.035407    0.593081    37.407054
# 97   10.513382     0.152059    0.035407    0.593081    37.407054
# 98   27.876563     0.152059    0.035407    0.593081    37.407054
# 99   22.937172     0.152059    0.035407    0.593081    37.407054
#
#    Quality_label  label
# 0           Pass      3
# 1           Fail      4
# 2           Fail      4
# 3           Fail      4
# 4           Fail      4
# 5           Good      2
# 6           Good      2
# 7           Good      2
# 8           Pass      3
# 9           Good      2
# 10          Pass      3
# 11          Good      2
# 12     Excellent      1
# 13          Pass      3
# 14          Good      2
# 15          Good      2
# 16          Fail      4
# 17          Fail      4
# 18     Excellent      1
# 19     Excellent      1
# 20     Excellent      1
# 21          Good      2
# 22     Excellent      1
# 23          Pass      3
# 24     Excellent      1
# 25          Pass      3
# 26     Excellent      1
# 27          Good      2
# 28     Excellent      1
# 29     Excellent      1
# ..           ...    ...
# 70          Good      2
# 71     Excellent      1
# 72          Pass      3
# 73          Good      2
# 74          Good      2
# 75          Pass      3
# 76     Excellent      1
# 77     Excellent      1
# 78          Pass      3
# 79          Good      2
# 80          Fail      4
# 81          Pass      3
# 82          Pass      3
# 83          Pass      3
# 84          Pass      3
# 85          Fail      4
# 86          Fail      4
# 87          Pass      3
# 88     Excellent      1
# 89     Excellent      1
# 90          Pass      3
# 91          Good      2
# 92          Pass      3
# 93          Pass      3
# 94          Good      2
# 95          Pass      3
# 96          Fail      4
# 97          Good      2
# 98          Pass      3
# 99          Pass      3
#
# [100 rows x 12 columns]

# %% [markdown]
# # Label Distribution

# %%
train['Quality_label'].value_counts().plot(kind='bar')

# %%
train['label'] = train['Quality_label'].map({
    'Excellent':1,
    'Good':2,
    'Pass':3,
    'Fail':4
})

# %%
train.describe()
# Out:
#           Parameter1    Parameter2     Parameter3     Parameter4  \
# count    6000.000000  6.000000e+03    6000.000000    6000.000000
# mean      485.198954  1.952379e+03     406.348529     189.205842
# std     11401.971393  5.419588e+04   12018.898941    2621.779049
# min         0.000003  1.683797e-07       0.000005       0.000002
# 25%         0.088221  4.765771e-02       0.102304       0.118314
# 50%         1.050304  9.405962e-01       1.044908       1.068467
# 75%        10.938565  1.569199e+01      10.665397       9.902064
# max    713682.207601  3.034568e+06  864530.632179  139767.494732
#
#          Parameter5    Parameter6    Parameter7    Parameter8    Parameter9  \
# count  6.000000e+03  6.000000e+03   6000.000000   6000.000000  6.000000e+03
# mean   5.868163e+00  5.598597e+00    272.300821     22.133231  5.823664e+04
# std    8.631865e+00  7.686898e+00   2027.460514    302.172768  3.173068e+06
# min    9.985942e-07  9.810610e-07      0.000624      0.023699  3.962831e-04
# 25%    7.416296e-01  3.818154e-01      0.152059      0.035407  5.930812e-01
# 50%    2.225808e+00  2.684398e+00      0.600827      2.931083  5.930812e-01
# 75%    6.680183e+00  7.117767e+00      2.374035     17.850021  6.783967e+00
# max    8.367195e+01  4.117541e+01  35698.591553  20086.397753  1.738083e+08
#
#        Parameter10        label
# count  6000.000000  6000.000000
# mean     35.902066     2.515667
# std     101.629348     0.957205
# min       0.001024     1.000000
# 25%       0.101478     2.000000
# 50%       0.727611     3.000000
# 75%      13.969790     3.000000
# max     517.197610     4.000000

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(12,8))
correlation = train.corr()
mask = np.zeros_like(correlation) # 返回来一个给定形状和类型的用0填充的数组
mask[np.triu_indices_from(mask)] = True #np.triu_indices_from(mask)返回矩阵上三角形的索引
sns.heatmap(data=correlation.round(3),mask=mask,vmin=-0.1,vmax=0.1,annot=True,linewidths=.1)

# %% [markdown]
# # 判断是否是类别变量

# %%
train.nunique().plot(kind='bar')

# %% [markdown]
# 总结：Parameter1~4数值差异性大，方差大，不适宜作为特征参数

# %% [markdown]
# ## Parameter与label

# %%
for i in ['Parameter' + str(i) for i in range(1,11)]:
    sns.scatterplot(x='Quality_label',y=i,data=train)
    plt.title(i)
    plt.show()

# %% [markdown]
# # 训练集与测试及分布比较

# %%
for i in ['Parameter' + str(i) for i in range(1,11)]:
    train[i].value_counts().plot(kind='bar',alpha=0.5,label='Train')
    test[i].value_counts().plot(kind='bar',alpha=0.5,color='red',label='Test')
    plt.title(i)
    plt.legend()
    plt.show()

# %%
for i in ['Parameter' + str(i) for i in range(1,11)]:
    sns.kdeplot(train[i],label='Train',alpha=0.8)
    sns.kdeplot(test[i],label='Test',alpha=0.8)
    plt.title(i)
    plt.show()
